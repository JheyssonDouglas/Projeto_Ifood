# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
df = pd.read_json('C:/Users/User/Desktop/Apresentação para ifood/Spotify/Spotify/StreamingHistory.json')
df.head()
# Out:
#             endTime  artistName       trackName  msPlayed
# 0  2020-07-20 02:13  Aura Lumin  Nature Ambient         0
# 1  2020-07-20 02:15  Aura Lumin  Nature Ambient     95910
# 2  2020-07-20 02:16  Aura Lumin       the Light     43381
# 3  2020-07-20 02:24  Aura Lumin         Destiny    236592
# 4  2020-07-20 07:02     Neewton            Dawn     64349

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415 entries, 0 to 414
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   endTime     415 non-null    object
#  1   artistName  415 non-null    object
#  2   trackName   415 non-null    object
#  3   msPlayed    415 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 13.1+ KB

# %%
# Alterando para datetime a coluna endtime e convertendo no horario(brasil UTC-03:00)  
df['endTime'] = pd.to_datetime(df['endTime'])

# Criando as colunas Ano,Mês, dia e dia da semana
df['Ano'], df['Mês'] = df['endTime'].dt.year, df['endTime'].dt.month_name()
df['Dia'] = df['endTime'].dt.day
df['hour'] = df['endTime'].dt.hour
df['Dia da Semana'] = df['endTime'].dt.day_name()
df['tempo'] = df['endTime'].dt.time
df['horas'] = df['endTime'].dt.hour
df['nomeDia'] = df['endTime'].map( lambda x: x.day_name())

# %%
df['tempo_Escutado(hr)'] = df['msPlayed']/3600000
df['tempo_Escutado(min)'] = df['msPlayed']/60000

# %%
df.head()
# Out:
#               endTime  artistName       trackName  msPlayed   Ano   Mês  Dia  \
# 0 2020-07-20 02:13:00  Aura Lumin  Nature Ambient         0  2020  July   20
# 1 2020-07-20 02:15:00  Aura Lumin  Nature Ambient     95910  2020  July   20
# 2 2020-07-20 02:16:00  Aura Lumin       the Light     43381  2020  July   20
# 3 2020-07-20 02:24:00  Aura Lumin         Destiny    236592  2020  July   20
# 4 2020-07-20 07:02:00     Neewton            Dawn     64349  2020  July   20
#
#    hour Dia da Semana     tempo  horas nomeDia  tempo_Escutado(hr)  \
# 0     2        Monday  02:13:00      2  Monday            0.000000
# 1     2        Monday  02:15:00      2  Monday            0.026642
# 2     2        Monday  02:16:00      2  Monday            0.012050
# 3     2        Monday  02:24:00      2  Monday            0.065720
# 4     7        Monday  07:02:00      7  Monday            0.017875
#
#    tempo_Escutado(min)
# 0             0.000000
# 1             1.598500
# 2             0.723017
# 3             3.943200
# 4             1.072483

# %%
def Parte_do_dia(x):
    if (x >= 6) and (x < 12):
        return 'Manhã'
    elif (x >= 12) and (x < 18):
        return 'Tarde'
    elif (x > 18) and (x < 23):
        return 'Noite'
    else:
        return 'Madrugada'

df['Parte do dia'] = df['endTime'].dt.hour.apply(Parte_do_dia)

# %%
df.head()
# Out:
#               endTime  artistName       trackName  msPlayed   Ano   Mês  Dia  \
# 0 2020-07-20 02:13:00  Aura Lumin  Nature Ambient         0  2020  July   20
# 1 2020-07-20 02:15:00  Aura Lumin  Nature Ambient     95910  2020  July   20
# 2 2020-07-20 02:16:00  Aura Lumin       the Light     43381  2020  July   20
# 3 2020-07-20 02:24:00  Aura Lumin         Destiny    236592  2020  July   20
# 4 2020-07-20 07:02:00     Neewton            Dawn     64349  2020  July   20
#
#    hour Dia da Semana     tempo  horas nomeDia  tempo_Escutado(hr)  \
# 0     2        Monday  02:13:00      2  Monday            0.000000
# 1     2        Monday  02:15:00      2  Monday            0.026642
# 2     2        Monday  02:16:00      2  Monday            0.012050
# 3     2        Monday  02:24:00      2  Monday            0.065720
# 4     7        Monday  07:02:00      7  Monday            0.017875
#
#    tempo_Escutado(min) Parte do dia
# 0             0.000000    Madrugada
# 1             1.598500    Madrugada
# 2             0.723017    Madrugada
# 3             3.943200    Madrugada
# 4             1.072483        Manhã

# %%
df['Dia da Semana'] = df['Dia da Semana'].map({'Monday':'Segunda-feira',
                             'Tuesday':'Terça-feira',
                             'Wednesday':'Quarta-feira',
                             'Thursday' : 'Quinta-feira',
                             'Friday' : 'Sexta-feira',
                             'Saturday' : 'Sábado',               
                             'Sunday' : 'Domingo',            
                             np.nan:'NY'},
                             na_action=None)

# %%
df['Mês'] = df['Mês'].map({'May' : 'Maio',               
                             'July' : 'Julho',                
                             np.nan:'NY'},
                             na_action=None)

# %%
df.head(2)
# Out:
#               endTime  artistName       trackName  msPlayed   Ano    Mês  Dia  \
# 0 2020-07-20 02:13:00  Aura Lumin  Nature Ambient         0  2020  Julho   20
# 1 2020-07-20 02:15:00  Aura Lumin  Nature Ambient     95910  2020  Julho   20
#
#    hour  Dia da Semana     tempo  horas nomeDia  tempo_Escutado(hr)  \
# 0     2  Segunda-feira  02:13:00      2  Monday            0.000000
# 1     2  Segunda-feira  02:15:00      2  Monday            0.026642
#
#    tempo_Escutado(min) Parte do dia
# 0               0.0000    Madrugada
# 1               1.5985    Madrugada

# %%
df = df.drop(columns=['hour','nomeDia'])
df.head()
# Out:
#               endTime  artistName       trackName  msPlayed   Ano    Mês  Dia  \
# 0 2020-07-20 02:13:00  Aura Lumin  Nature Ambient         0  2020  Julho   20
# 1 2020-07-20 02:15:00  Aura Lumin  Nature Ambient     95910  2020  Julho   20
# 2 2020-07-20 02:16:00  Aura Lumin       the Light     43381  2020  Julho   20
# 3 2020-07-20 02:24:00  Aura Lumin         Destiny    236592  2020  Julho   20
# 4 2020-07-20 07:02:00     Neewton            Dawn     64349  2020  Julho   20
#
#    Dia da Semana     tempo  horas  tempo_Escutado(hr)  tempo_Escutado(min)  \
# 0  Segunda-feira  02:13:00      2            0.000000             0.000000
# 1  Segunda-feira  02:15:00      2            0.026642             1.598500
# 2  Segunda-feira  02:16:00      2            0.012050             0.723017
# 3  Segunda-feira  02:24:00      2            0.065720             3.943200
# 4  Segunda-feira  07:02:00      7            0.017875             1.072483
#
#   Parte do dia
# 0    Madrugada
# 1    Madrugada
# 2    Madrugada
# 3    Madrugada
# 4        Manhã

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415 entries, 0 to 414
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   endTime              415 non-null    datetime64[ns]
#  1   artistName           415 non-null    object
#  2   trackName            415 non-null    object
#  3   msPlayed             415 non-null    int64
#  4   Ano                  415 non-null    int64
#  5   Mês                  415 non-null    object
#  6   Dia                  415 non-null    int64
#  7   Dia da Semana        415 non-null    object
#  8   tempo                415 non-null    object
#  9   horas                415 non-null    int64
#  10  tempo_Escutado(hr)   415 non-null    float64
#  11  tempo_Escutado(min)  415 non-null    float64
#  12  Parte do dia         415 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(6)
# memory usage: 42.3+ KB

# %%
df.dtypes
# Out:
# endTime                datetime64[ns]
# artistName                     object
# trackName                      object
# msPlayed                        int64
# Ano                             int64
# Mês                            object
# Dia                             int64
# Dia da Semana                  object
# tempo                          object
# horas                           int64
# tempo_Escutado(hr)            float64
# tempo_Escutado(min)           float64
# Parte do dia                   object
# dtype: object

# %%
df.describe()
# Out:
#            msPlayed          Ano         Dia       horas  tempo_Escutado(hr)  \
# count  4.150000e+02   415.000000  415.000000  415.000000          415.000000
# mean   1.727517e+05  2020.971084   11.737349   16.578313            0.047987
# std    1.608005e+05     0.167772    5.213410    6.664711            0.044667
# min    0.000000e+00  2020.000000    1.000000    0.000000            0.000000
# 25%    5.750950e+04  2021.000000    8.000000   14.500000            0.015975
# 50%    1.813020e+05  2021.000000   13.000000   18.000000            0.050362
# 75%    2.277335e+05  2021.000000   16.000000   22.000000            0.063259
# max    2.064664e+06  2021.000000   21.000000   23.000000            0.573518
#
#        tempo_Escutado(min)
# count           415.000000
# mean              2.879195
# std               2.680009
# min               0.000000
# 25%               0.958492
# 50%               3.021700
# 75%               3.795558
# max              34.411067

# %%
# Tempo escutado em horas

df['tempo_Escutado(hr)'].sum()
# Out:
# 19.914434166666666

# %%
# Tempo escutado em minutos

df['tempo_Escutado(min)'].sum()
# Out:
# 1194.86605

# %%
minutos = df['tempo_Escutado(min)'].sum()
horas = minutos/60
dias = horas/24
print('{} dias {} horas e {} minutos'.format(int(dias), 
                                int(horas)-24*int(dias),
                                int(minutos)-60*(24*int(dias) + (int(horas)-24*int(dias)))
                                ))
# Out:
# 0 dias 19 horas e 54 minutos

# %%
df.head()
# Out:
#               endTime  artistName       trackName  msPlayed   Ano    Mês  Dia  \
# 0 2020-07-20 02:13:00  Aura Lumin  Nature Ambient         0  2020  Julho   20
# 1 2020-07-20 02:15:00  Aura Lumin  Nature Ambient     95910  2020  Julho   20
# 2 2020-07-20 02:16:00  Aura Lumin       the Light     43381  2020  Julho   20
# 3 2020-07-20 02:24:00  Aura Lumin         Destiny    236592  2020  Julho   20
# 4 2020-07-20 07:02:00     Neewton            Dawn     64349  2020  Julho   20
#
#    Dia da Semana     tempo  horas  tempo_Escutado(hr)  tempo_Escutado(min)  \
# 0  Segunda-feira  02:13:00      2            0.000000             0.000000
# 1  Segunda-feira  02:15:00      2            0.026642             1.598500
# 2  Segunda-feira  02:16:00      2            0.012050             0.723017
# 3  Segunda-feira  02:24:00      2            0.065720             3.943200
# 4  Segunda-feira  07:02:00      7            0.017875             1.072483
#
#   Parte do dia
# 0    Madrugada
# 1    Madrugada
# 2    Madrugada
# 3    Madrugada
# 4        Manhã

# %%
# Dia da semana (em minutos) que mais escutei spotify

df.groupby(['Dia da Semana']).agg({'tempo_Escutado(min)':'sum'}).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Dia da Semana'>

# %%
# Dia da semana (em horas) que mais escutei spotify

df.groupby(['Dia da Semana']).agg({'tempo_Escutado(hr)':'sum'}).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Dia da Semana'>

# %%
df['Ano'].value_counts()
# Out:
# 2021    403
# 2020     12
# Name: Ano, dtype: int64

# %%
# Ano que mais utilizei o spotify

df['Ano'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.groupby(['Mês']).agg({'Ano':'sum'})
# Out:
#           Ano
# Mês
# Julho  826577
# Maio    12126

# %%
df['Mês'].value_counts()
# Out:
# Julho    409
# Maio       6
# Name: Mês, dtype: int64

# %%
df['Mês'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['artistName'].value_counts().head(10)
# Out:
# Vintage Culture    67
# RÜFÜS DU SOL       21
# Dubdogz            20
# Elderbrook         12
# Mochakk            10
# Dashdot             9
# Koradize            9
# Cherub              9
# VINNE               9
# Sono                9
# Name: artistName, dtype: int64

# %%
df['artistName'].value_counts().head(10).plot.barh()
# Out:
# <AxesSubplot:>

# %%
df['trackName'].value_counts().head(10)
# Out:
# Pumped up Kicks (feat. Joy Corporation)                    11
# Sometimes                                                  11
# Losing - Remix                                             11
# In The Dark                                                10
# I Will Find                                                 9
# Baile da Roosevelt (Pam Pararam)                            9
# Doses & Mimosas                                             9
# Keep Control - ARTBAT Remix                                 9
# Buttercup                                                   9
# Love Tonight - Vintage Culture & Kiko Franco Remix Edit     8
# Name: trackName, dtype: int64

# %%
df['trackName'].value_counts().head(10).plot.barh()
# Out:
# <AxesSubplot:>

# %%
df['Dia da Semana'].value_counts().head(10).plot.barh()
# Out:
# <AxesSubplot:>

# %%
df['artistName'].value_counts().head(10).plot.barh()
# Out:
# <AxesSubplot:>

# %%
df['Parte do dia'].value_counts().head(10)
# Out:
# Noite        162
# Tarde        132
# Madrugada    117
# Manhã          4
# Name: Parte do dia, dtype: int64

# %%
df['Parte do dia'].value_counts().head(10).plot.barh()
# Out:
# <AxesSubplot:>

# %%
#nuvem de palavras das musicas
text = df.trackName.values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (10, 20))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#nuvem de palavras das musicas
text = df.artistName.values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (10, 20))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
df.head(2)
# Out:
#               endTime  artistName       trackName  msPlayed   Ano    Mês  Dia  \
# 0 2020-07-20 02:13:00  Aura Lumin  Nature Ambient         0  2020  Julho   20
# 1 2020-07-20 02:15:00  Aura Lumin  Nature Ambient     95910  2020  Julho   20
#
#    Dia da Semana     tempo  horas  tempo_Escutado(hr)  tempo_Escutado(min)  \
# 0  Segunda-feira  02:13:00      2            0.000000               0.0000
# 1  Segunda-feira  02:15:00      2            0.026642               1.5985
#
#   Parte do dia
# 0    Madrugada
# 1    Madrugada

# %%
df.to_csv('APRESENTAÇÃO IFOOD/dados_SPOTIFY.csv', index=False)
